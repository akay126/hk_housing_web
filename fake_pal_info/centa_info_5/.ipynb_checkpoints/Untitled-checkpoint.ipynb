# %%
import pandas as pd

list_code = pd.read_csv('centapart.csv')

list_code.index = list_code['flat_code']

list_code
# Out:
#                      Block     Name               Phase   bldg_code  \
# flat_code
# SSPPWSPEPSPPBS  THE MERTON  TOWER 1          THE MERTON  SSPPWSPEPS
# SSPPWSPEPSPPBP  THE MERTON  TOWER 1          THE MERTON  SSPPWSPEPS
# SSPPWSPEPSPPKY  THE MERTON  TOWER 1          THE MERTON  SSPPWSPEPS
# SSPPWSPEPSPPKD  THE MERTON  TOWER 1          THE MERTON  SSPPWSPEPS
# SSPPWSPEPSPPKG  THE MERTON  TOWER 1          THE MERTON  SSPPWSPEPS
# SSPPWSPEPSPPKB  THE MERTON  TOWER 1          THE MERTON  SSPPWSPEPS
# SSPPWSPEPSPPKK  THE MERTON  TOWER 1          THE MERTON  SSPPWSPEPS
# SSPPWSPEPSPPKA  THE MERTON  TOWER 1          THE MERTON  SSPPWSPEPS
# SSPPWSPEPSPPKE  THE MERTON  TOWER 1          THE MERTON  SSPPWSPEPS
# SSPPWSPEPSPPKS  THE MERTON  TOWER 1          THE MERTON  SSPPWSPEPS
# SSPPWSPEPSPPKP  THE MERTON  TOWER 1          THE MERTON  SSPPWSPEPS
# SSPPWSPEPSPPAW  THE MERTON  TOWER 1          THE MERTON  SSPPWSPEPS
# SSPPWSPEPSPPAY  THE MERTON  TOWER 1          THE MERTON  SSPPWSPEPS
# ...
